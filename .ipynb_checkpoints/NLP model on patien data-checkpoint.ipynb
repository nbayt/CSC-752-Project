# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import re
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
file_path = "C:\\Users\\alan\\Medical Image Project\\BrEaST-Lesions-USG-clinical-data-Dec-15-2023.xlsx"

df = pd.read_excel(file_path)
df
# Out:
#      CaseID Image_filename Mask_tumor_filename Mask_other_filename  \
# 0         1    case001.png   case001_tumor.png                 NaN
# 1         2    case002.png   case002_tumor.png                 NaN
# 2         3    case003.png   case003_tumor.png                 NaN
# 3         4    case004.png   case004_tumor.png                 NaN
# 4         5    case005.png   case005_tumor.png                 NaN
# ..      ...            ...                 ...                 ...
# 251     252    case252.png   case252_tumor.png                 NaN
# 252     253    case253.png   case253_tumor.png                 NaN
# 253     254    case254.png   case254_tumor.png                 NaN
# 254     255    case255.png   case255_tumor.png                 NaN
# 255     256    case256.png   case256_tumor.png                 NaN
#
#      Pixel_size            Age                           Tissue_composition  \
# 0      0.007812             57             heterogeneous: predominantly fat
# 1      0.006462  not available                             homogeneous: fat
# 2      0.006944             56             heterogeneous: predominantly fat
# 3      0.007812             43                  homogeneous: fibroglandular
# 4      0.007812             67                             homogeneous: fat
# ..          ...            ...                                          ...
# 251    0.006944             18                  homogeneous: fibroglandular
# 252    0.007812             64                             homogeneous: fat
# 253    0.007812             57             heterogeneous: predominantly fat
# 254    0.006944             42  heterogeneous: predominantly fibroglandular
# 255    0.007812             38                  homogeneous: fibroglandular
#
#                           Signs                                 Symptoms  \
# 0                   breast scar  family history of breast/ovarian cancer
# 1                 not available                            not available
# 2                            no                         nipple discharge
# 3                            no                                       no
# 4    nipple retraction&palpable  family history of breast/ovarian cancer
# ..                          ...                                      ...
# 251                    palpable                                       no
# 252        palpable&breast scar  family history of breast/ovarian cancer
# 253                          no                                       no
# 254                    palpable  family history of breast/ovarian cancer
# 255                    palpable               HRT/hormonal contraception
#
#          Shape  ...          Echogenicity Posterior_features Halo  \
# 0    irregular  ...         heterogeneous          shadowing   no
# 1         oval  ...            hypoechoic                 no   no
# 2         oval  ...           hyperechoic                 no   no
# 3        round  ...            hypoechoic                 no   no
# 4         oval  ...  complex cystic/solid        enhancement   no
# ..         ...  ...                   ...                ...  ...
# 251       oval  ...            hypoechoic                 no   no
# 252       oval  ...              anechoic        enhancement   no
# 253  irregular  ...            hypoechoic          shadowing   no
# 254  irregular  ...         heterogeneous          shadowing   no
# 255       oval  ...         heterogeneous                 no   no
#
#     Calcifications Skin_thickening  \
# 0               no             yes
# 1               no              no
# 2               no              no
# 3               no              no
# 4               no              no
# ..             ...             ...
# 251             no              no
# 252             no             yes
# 253             no              no
# 254    intraductal              no
# 255             no              no
#
#                                         Interpretation BIRADS  \
# 0     Breast scar (surgery)&Breast scar (radiotherapy)      2
# 1                               Dysplasia&Fibroadenoma     4b
# 2    Duct filled with thick fluid&Intraductal papil...     4a
# 3                         Cyst filled with thick fluid      3
# 4        Suspicion of malignancy&Intraductal papilloma     4b
# ..                                                 ...    ...
# 251                                       Fibroadenoma     4a
# 252                 Fat necrosis&Breast scar (surgery)      2
# 253                            Suspicion of malignancy      5
# 254                   Suspicion of malignancy&Mastitis     4c
# 255                                       Fibroadenoma     4a
#
#                     Verification  \
# 0    confirmed by follow-up care
# 1            confirmed by biopsy
# 2            confirmed by biopsy
# 3    confirmed by follow-up care
# 4            confirmed by biopsy
# ..                           ...
# 251          confirmed by biopsy
# 252  confirmed by follow-up care
# 253          confirmed by biopsy
# 254          confirmed by biopsy
# 255          confirmed by biopsy
#
#                                              Diagnosis Classification
# 0                                       not applicable         benign
# 1                              Intramammary lymph node         benign
# 2    Usual ductal hyperplasia (UDH)&Pseudoangiomato...         benign
# 3                                       not applicable         benign
# 4    Encapsulated papillary carcinoma&Ductal carcin...      malignant
# ..                                                 ...            ...
# 251                                       Fibroadenoma         benign
# 252                                     not applicable         benign
# 253  Invasive carcinoma of no special type (NST)&Du...      malignant
# 254                    Ductal carcinoma in situ (DCIS)      malignant
# 255                                       Fibroadenoma         benign
#
# [256 rows x 21 columns]

# %%
# Preprocessing
columns_to_drop = ["Image_filename", "Mask_tumor_filename","Mask_other_filename", "Pixel_size", "Verification","BIRADS"]
new_df = df.drop(columns=columns_to_drop)


# handling missing Age
new_df_filtered = new_df[new_df['Age'] != 'not available']
new_df_filtered['Age'] = pd.to_numeric(new_df_filtered['Age'])
age_mean_corrected = new_df_filtered['Age'].mean()

# Replace 'not available' with the calculated mean age in the original new_df
new_df['Age'] = new_df['Age'].replace('not available', age_mean_corrected)
new_df['Age'] = pd.to_numeric(new_df['Age'], errors='coerce')
new_df['Age'] = new_df['Age'].astype(int)

# Drop rows where the 'Classification' column does not contain 'benign' or 'malignant'
final_df = new_df[(new_df['Classification'] == 'benign') | (new_df['Classification'] == 'malignant')]

label = final_df['Classification']
final_df = final_df.drop('Classification', axis=1)
final_df
# Out:
# C:\Users\alan\AppData\Local\Temp\ipykernel_17260\2673460380.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df_filtered['Age'] = pd.to_numeric(new_df_filtered['Age'])
#      CaseID  Age                           Tissue_composition  \
# 0         1   57             heterogeneous: predominantly fat
# 1         2   53                             homogeneous: fat
# 2         3   56             heterogeneous: predominantly fat
# 3         4   43                  homogeneous: fibroglandular
# 4         5   67                             homogeneous: fat
# ..      ...  ...                                          ...
# 251     252   18                  homogeneous: fibroglandular
# 252     253   64                             homogeneous: fat
# 253     254   57             heterogeneous: predominantly fat
# 254     255   42  heterogeneous: predominantly fibroglandular
# 255     256   38                  homogeneous: fibroglandular
#
#                           Signs                                 Symptoms  \
# 0                   breast scar  family history of breast/ovarian cancer
# 1                 not available                            not available
# 2                            no                         nipple discharge
# 3                            no                                       no
# 4    nipple retraction&palpable  family history of breast/ovarian cancer
# ..                          ...                                      ...
# 251                    palpable                                       no
# 252        palpable&breast scar  family history of breast/ovarian cancer
# 253                          no                                       no
# 254                    palpable  family history of breast/ovarian cancer
# 255                    palpable               HRT/hormonal contraception
#
#          Shape                                         Margin  \
# 0    irregular                 not circumscribed - indistinct
# 1         oval                 not circumscribed - indistinct
# 2         oval                                  circumscribed
# 3        round                                  circumscribed
# 4         oval                                  circumscribed
# ..         ...                                            ...
# 251       oval                                  circumscribed
# 252       oval                                  circumscribed
# 253  irregular  not circumscribed - microlobulated&indistinct
# 254  irregular  not circumscribed - microlobulated&indistinct
# 255       oval                                  circumscribed
#
#              Echogenicity Posterior_features Halo Calcifications  \
# 0           heterogeneous          shadowing   no             no
# 1              hypoechoic                 no   no             no
# 2             hyperechoic                 no   no             no
# 3              hypoechoic                 no   no             no
# 4    complex cystic/solid        enhancement   no             no
# ..                    ...                ...  ...            ...
# 251            hypoechoic                 no   no             no
# 252              anechoic        enhancement   no             no
# 253            hypoechoic          shadowing   no             no
# 254         heterogeneous          shadowing   no    intraductal
# 255         heterogeneous                 no   no             no
#
#     Skin_thickening                                     Interpretation  \
# 0               yes   Breast scar (surgery)&Breast scar (radiotherapy)
# 1                no                             Dysplasia&Fibroadenoma
# 2                no  Duct filled with thick fluid&Intraductal papil...
# 3                no                       Cyst filled with thick fluid
# 4                no      Suspicion of malignancy&Intraductal papilloma
# ..              ...                                                ...
# 251              no                                       Fibroadenoma
# 252             yes                 Fat necrosis&Breast scar (surgery)
# 253              no                            Suspicion of malignancy
# 254              no                   Suspicion of malignancy&Mastitis
# 255              no                                       Fibroadenoma
#
#                                              Diagnosis
# 0                                       not applicable
# 1                              Intramammary lymph node
# 2    Usual ductal hyperplasia (UDH)&Pseudoangiomato...
# 3                                       not applicable
# 4    Encapsulated papillary carcinoma&Ductal carcin...
# ..                                                 ...
# 251                                       Fibroadenoma
# 252                                     not applicable
# 253  Invasive carcinoma of no special type (NST)&Du...
# 254                    Ductal carcinoma in situ (DCIS)
# 255                                       Fibroadenoma
#
# [252 rows x 14 columns]

# %%
# NLP feature extraction

non_numerical_columns = [col for col in final_df.columns if final_df[col].dtype == 'object' and col not in ['CaseID', 'Age']]
# TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=100, stop_words='english')

for column in non_numerical_columns:
    # Convert column to string
    column_as_string = final_df[column].astype(str).fillna('')
    tfidf_matrix = tfidf_vectorizer.fit_transform(column_as_string)
    
    feature_names = [f"{column}_{word}" for word in tfidf_vectorizer.get_feature_names_out()]
    tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)
    
    # Concatenate TF-IDF 
    if 'final_numerical_df' in locals():
        final_numerical_df = pd.concat([final_numerical_df, tfidf_df], axis=1)
    else:
        final_numerical_df = tfidf_df.copy()

        
final_numerical_df = pd.concat([final_df[['CaseID', 'Age']].reset_index(drop=True), final_numerical_df.reset_index(drop=True)], axis=1)

# Check the shape
final_numerical_df.shape, final_numerical_df.head()
# Out:
# ((252, 2809),
#     CaseID  Age  CaseID  Age  CaseID  Age  CaseID  Age  CaseID  Age  ...  \
#  0       1   57       1   57       1   57       1   57       1   57  ...
#  1       2   53       2   53       2   53       2   53       2   53  ...
#  2       3   56       3   56       3   56       3   56       3   56  ...
#  3       4   43       4   43       4   43       4   43       4   43  ...
#  4       5   67       5   67       5   67       5   67       5   67  ...
#
#     Diagnosis_simple  Diagnosis_situ  Diagnosis_solid  Diagnosis_special  \
#  0               0.0         0.00000              0.0                0.0
#  1               0.0         0.00000              0.0                0.0
#  2               0.0         0.00000              0.0                0.0
#  3               0.0         0.00000              0.0                0.0
#  4               0.0         0.35084              0.0                0.0
#
#     Diagnosis_stromal  Diagnosis_tubular  Diagnosis_tumor  Diagnosis_type  \
#  0           0.000000                0.0              0.0             0.0
#  1           0.000000                0.0              0.0             0.0
#  2           0.346461                0.0              0.0             0.0
#  3           0.000000                0.0              0.0             0.0
#  4           0.000000                0.0              0.0             0.0
#
#     Diagnosis_udh  Diagnosis_usual
#  0       0.000000         0.000000
#  1       0.000000         0.000000
#  2       0.336376         0.336376
#  3       0.000000         0.000000
#  4       0.000000         0.000000
#
#  [5 rows x 2809 columns])

# %%
final_numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Columns: 2809 entries, CaseID to Diagnosis_usual
# dtypes: float64(2757), int32(26), int64(26)
# memory usage: 5.4 MB

# %%
# split the data
X = final_numerical_df

encoder = LabelEncoder()
y = encoder.fit_transform(label)

# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((226, 2809), (26, 2809), (226,), (26,))

# %%
# model Building

input_shape = X_train.shape[1]

# Model
model = Sequential([
    Dense(128, activation='relu', input_shape=(input_shape,)),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')  # Sigmoid for binary classification
])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',  
              metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_116 (Dense)           (None, 128)               359680
#
#  dropout_54 (Dropout)        (None, 128)               0
#
#  dense_117 (Dense)           (None, 64)                8256
#
#  dropout_55 (Dropout)        (None, 64)                0
#
#  dense_118 (Dense)           (None, 32)                2080
#
#  dense_119 (Dense)           (None, 1)                 33
#
# =================================================================
# Total params: 370,049
# Trainable params: 370,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X_train, y_train,
                    epochs=50,  
                    batch_size=4,  
                    validation_split=0.2,  
                    verbose=1)
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)

print(f"Test Loss: {test_loss}\nTest Accuracy: {test_accuracy}")
# Out:
# Epoch 1/50
# 45/45 [==============================] - 1s 8ms/step - loss: 2.5749 - accuracy: 0.5778 - val_loss: 0.4858 - val_accuracy: 0.6957
# Epoch 2/50
# 45/45 [==============================] - 0s 5ms/step - loss: 1.7242 - accuracy: 0.5389 - val_loss: 0.9419 - val_accuracy: 0.5870
# Epoch 3/50
# 45/45 [==============================] - 0s 5ms/step - loss: 1.0287 - accuracy: 0.6222 - val_loss: 0.6941 - val_accuracy: 0.6304
# Epoch 4/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.8669 - accuracy: 0.7000 - val_loss: 0.4392 - val_accuracy: 0.8043
# Epoch 5/50
# 45/45 [==============================] - 0s 5ms/step - loss: 1.0374 - accuracy: 0.5889 - val_loss: 0.5281 - val_accuracy: 0.7609
# Epoch 6/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6570 - accuracy: 0.7056 - val_loss: 0.4324 - val_accuracy: 0.8913
# Epoch 7/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.6676 - accuracy: 0.6833 - val_loss: 0.4784 - val_accuracy: 0.8261
# Epoch 8/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5994 - accuracy: 0.6833 - val_loss: 0.3244 - val_accuracy: 0.9348
# Epoch 9/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5172 - accuracy: 0.7556 - val_loss: 0.3674 - val_accuracy: 0.8478
# Epoch 10/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5364 - accuracy: 0.7556 - val_loss: 0.3780 - val_accuracy: 0.9130
# Epoch 11/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.5637 - accuracy: 0.7000 - val_loss: 0.4499 - val_accuracy: 0.7174
# Epoch 12/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4943 - accuracy: 0.7667 - val_loss: 0.2974 - val_accuracy: 0.8913
# Epoch 13/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4356 - accuracy: 0.8056 - val_loss: 0.3220 - val_accuracy: 0.8913
# Epoch 14/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.4157 - accuracy: 0.8111 - val_loss: 0.3011 - val_accuracy: 0.8913
# Epoch 15/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3691 - accuracy: 0.8500 - val_loss: 0.3733 - val_accuracy: 0.8478
# Epoch 16/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.3941 - accuracy: 0.8333 - val_loss: 0.2583 - val_accuracy: 0.8696
# Epoch 17/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2917 - accuracy: 0.8722 - val_loss: 0.2719 - val_accuracy: 0.9130
# Epoch 18/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.2764 - accuracy: 0.8611 - val_loss: 0.3013 - val_accuracy: 0.9130
# Epoch 19/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3815 - accuracy: 0.8222 - val_loss: 0.3322 - val_accuracy: 0.8913
# Epoch 20/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3133 - accuracy: 0.8500 - val_loss: 0.2348 - val_accuracy: 0.8913
# Epoch 21/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3326 - accuracy: 0.8000 - val_loss: 0.4305 - val_accuracy: 0.7174
# Epoch 22/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2361 - accuracy: 0.9056 - val_loss: 0.3727 - val_accuracy: 0.8478
# Epoch 23/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3546 - accuracy: 0.8278 - val_loss: 0.1998 - val_accuracy: 0.8913
# Epoch 24/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2977 - accuracy: 0.8500 - val_loss: 0.2898 - val_accuracy: 0.8913
# Epoch 25/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3469 - accuracy: 0.8167 - val_loss: 0.2594 - val_accuracy: 0.9130
# Epoch 26/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3036 - accuracy: 0.8389 - val_loss: 0.2398 - val_accuracy: 0.9348
# Epoch 27/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2824 - accuracy: 0.8389 - val_loss: 0.7349 - val_accuracy: 0.8043
# Epoch 28/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.4502 - accuracy: 0.8278 - val_loss: 0.2727 - val_accuracy: 0.9130
# Epoch 29/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.2531 - accuracy: 0.9000 - val_loss: 0.2825 - val_accuracy: 0.9130
# Epoch 30/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1655 - accuracy: 0.9222 - val_loss: 0.2778 - val_accuracy: 0.9348
# Epoch 31/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.1910 - accuracy: 0.9444 - val_loss: 0.2557 - val_accuracy: 0.9130
# Epoch 32/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2022 - accuracy: 0.9111 - val_loss: 0.3012 - val_accuracy: 0.9130
# Epoch 33/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2092 - accuracy: 0.9278 - val_loss: 0.2664 - val_accuracy: 0.8913
# Epoch 34/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.1866 - accuracy: 0.9167 - val_loss: 0.2488 - val_accuracy: 0.9130
# Epoch 35/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2115 - accuracy: 0.8889 - val_loss: 0.2487 - val_accuracy: 0.9130
# Epoch 36/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1672 - accuracy: 0.9333 - val_loss: 0.2495 - val_accuracy: 0.8913
# Epoch 37/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1831 - accuracy: 0.9222 - val_loss: 0.2534 - val_accuracy: 0.9348
# Epoch 38/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1238 - accuracy: 0.9333 - val_loss: 0.3861 - val_accuracy: 0.8696
# Epoch 39/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0896 - accuracy: 0.9556 - val_loss: 0.3324 - val_accuracy: 0.8913
# Epoch 40/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1468 - accuracy: 0.9389 - val_loss: 0.2980 - val_accuracy: 0.9130
# Epoch 41/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1080 - accuracy: 0.9556 - val_loss: 0.2093 - val_accuracy: 0.9130
# Epoch 42/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1777 - accuracy: 0.9111 - val_loss: 0.2250 - val_accuracy: 0.8913
# Epoch 43/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1139 - accuracy: 0.9500 - val_loss: 0.2988 - val_accuracy: 0.9348
# Epoch 44/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.2132 - accuracy: 0.9056 - val_loss: 0.2050 - val_accuracy: 0.9348
# Epoch 45/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.2634 - accuracy: 0.8889 - val_loss: 0.3566 - val_accuracy: 0.8261
# Epoch 46/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.3088 - accuracy: 0.8778 - val_loss: 0.2659 - val_accuracy: 0.8913
# Epoch 47/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1535 - accuracy: 0.9500 - val_loss: 0.1984 - val_accuracy: 0.9348
# Epoch 48/50
# 45/45 [==============================] - 0s 6ms/step - loss: 0.1332 - accuracy: 0.9667 - val_loss: 0.3047 - val_accuracy: 0.8913
# Epoch 49/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1773 - accuracy: 0.9278 - val_loss: 0.2068 - val_accuracy: 0.9348
# Epoch 50/50
# 45/45 [==============================] - 0s 5ms/step - loss: 0.1484 - accuracy: 0.9333 - val_loss: 0.2578 - val_accuracy: 0.9348
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4016 - accuracy: 0.8846
# Test Loss: 0.4015856087207794
# Test Accuracy: 0.8846153616905212

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
model.save('C:/Users/alan/Medical Image Project/NLP model.h5')
